# %%
import numpy as np
import random
number = np.random.randint(1, 101)

print("Альтер-эго компьютера загадало число в диапазоне от 1 до 100 \n")
def BinarySearch(number):                      # функция бинарного поиска числа
    low = 1                                    # нижняя граница диапазона
    high = 100                                 # верхняя граница диапазона
    predict = (low+high)//2                    # предполагаемое число
    index = 0
    global count
    count = 1
    while predict != number:                   # повторить цикл, если предполагаемое число не равно загаданному
        predict = (low+high)//2
        count += 1
        print("Компьютер предполагает, что это число...", predict)
        if predict > number:                   # если предполагаемое число меньше, присвоить значение верхней границе
            high = predict
            print("Загаданное число меньше")
        elif predict < number:                 # если предполагаемое число больше, присвоить значение нижней границе
            low = predict + 1
            print("Загаданное число больше")
        elif predict == number:
            print("Верно \n \n")          
    return index + count
    return countBinarySearch(number)

BinarySearch(number)

def score_game(game_core):
    count_ls = []
    np.random.seed(1)
    random_array = np.random.randint(1,101, size=(1000))
    for number in random_array:
        count_ls.append(game_core(number))        
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")

score_game(BinarySearch)
# Out:
# Альтер-эго компьютера загадало число в диапазоне от 1 до 100
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число меньше
# Компьютер предполагает, что это число... 27
# Загаданное число больше
# Компьютер предполагает, что это число... 28
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Загаданное число больше
# Компьютер предполагает, что это число... 74
# Загаданное число меньше
# Компьютер предполагает, что это число... 73
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Загаданное число меньше
# Компьютер предполагает, что это число... 76
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число больше
# Компьютер предполагает, что это число... 6
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число больше
# Компьютер предполагает, что это число... 81
# Загаданное число меньше
# Компьютер предполагает, что это число... 80
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число меньше
# Компьютер предполагает, что это число... 66
# Загаданное число меньше
# Компьютер предполагает, что это число... 65
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число меньше
# Компьютер предполагает, что это число... 16
# Загаданное число больше
# Компьютер предполагает, что это число... 18
# Загаданное число меньше
# Компьютер предполагает, что это число... 17
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число меньше
# Компьютер предполагает, что это число... 2
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число меньше
# Компьютер предполагает, что это число... 27
# Загаданное число меньше
# Компьютер предполагает, что это число... 26
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число меньше
# Компьютер предполагает, что это число... 52
# Загаданное число меньше
# Компьютер предполагает, что это число... 51
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число меньше
# Компьютер предполагает, что это число... 21
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число больше
# Компьютер предполагает, что это число... 85
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Загаданное число больше
# Компьютер предполагает, что это число... 12
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число больше
# Компьютер предполагает, что это число... 31
# Загаданное число меньше
# Компьютер предполагает, что это число... 30
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число меньше
# Компьютер предполагает, что это число... 16
# Загаданное число меньше
# Компьютер предполагает, что это число... 15
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число меньше
# Компьютер предполагает, что это число... 52
# Загаданное число меньше
# Компьютер предполагает, что это число... 51
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число больше
# Компьютер предполагает, что это число... 97
# Загаданное число меньше
# Компьютер предполагает, что это число... 96
# Загаданное число меньше
# Компьютер предполагает, что это число... 95
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число больше
# Компьютер предполагает, что это число... 97
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число больше
# Компьютер предполагает, что это число... 85
# Загаданное число больше
# Компьютер предполагает, что это число... 87
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число меньше
# Компьютер предполагает, что это число... 16
# Загаданное число меньше
# Компьютер предполагает, что это число... 15
# Загаданное число меньше
# Компьютер предполагает, что это число... 14
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Загаданное число меньше
# Компьютер предполагает, что это число... 9
# Загаданное число меньше
# Компьютер предполагает, что это число... 8
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число меньше
# Компьютер предполагает, что это число... 66
# Загаданное число меньше
# Компьютер предполагает, что это число... 65
# Загаданное число меньше
# Компьютер предполагает, что это число... 64
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число больше
# Компьютер предполагает, что это число... 62
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число больше
# Компьютер предполагает, что это число... 24
# Загаданное число меньше
# Компьютер предполагает, что это число... 23
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число меньше
# Компьютер предполагает, что это число... 59
# Загаданное число меньше
# Компьютер предполагает, что это число... 58
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число меньше
# Компьютер предполагает, что это число... 2
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число меньше
# Компьютер предполагает, что это число... 2
# Загаданное число меньше
# Компьютер предполагает, что это число... 1
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число больше
# Компьютер предполагает, что это число... 62
# Загаданное число меньше
# Компьютер предполагает, что это число... 61
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Загаданное число меньше
# Компьютер предполагает, что это число... 9
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число меньше
# Компьютер предполагает, что это число... 91
# Загаданное число меньше
# Компьютер предполагает, что это число... 90
# Загаданное число меньше
# Компьютер предполагает, что это число... 89
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число меньше
# Компьютер предполагает, что это число... 16
# Загаданное число меньше
# Компьютер предполагает, что это число... 15
# Загаданное число меньше
# Компьютер предполагает, что это число... 14
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число больше
# Компьютер предполагает, что это число... 47
# Загаданное число больше
# Компьютер предполагает, что это число... 49
# Загаданное число меньше
# Компьютер предполагает, что это число... 48
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Загаданное число больше
# Компьютер предполагает, что это число... 74
# Загаданное число меньше
# Компьютер предполагает, что это число... 73
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число больше
# Компьютер предполагает, что это число... 31
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Загаданное число меньше
# Компьютер предполагает, что это число... 71
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число меньше
# Компьютер предполагает, что это число... 59
# Загаданное число меньше
# Компьютер предполагает, что это число... 58
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число меньше
# Компьютер предполагает, что это число... 27
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число меньше
# Компьютер предполагает, что это число... 52
# Загаданное число больше
# Компьютер предполагает, что это число... 53
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число больше
# Компьютер предполагает, что это число... 81
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число меньше
# Компьютер предполагает, что это число... 41
# Загаданное число больше
# Компьютер предполагает, что это число... 43
# Загаданное число меньше
# Компьютер предполагает, что это число... 42
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число больше
# Компьютер предполагает, что это число... 85
# Загаданное число меньше
# Компьютер предполагает, что это число... 84
# Загаданное число меньше
# Компьютер предполагает, что это число... 83
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число меньше
# Компьютер предполагает, что это число... 16
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число меньше
# Компьютер предполагает, что это число... 66
# Загаданное число меньше
# Компьютер предполагает, что это число... 65
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число меньше
# Компьютер предполагает, что это число... 27
# Загаданное число меньше
# Компьютер предполагает, что это число... 26
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число больше
# Компьютер предполагает, что это число... 97
# Загаданное число больше
# Компьютер предполагает, что это число... 99
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Загаданное число меньше
# Компьютер предполагает, что это число... 9
# Загаданное число меньше
# Компьютер предполагает, что это число... 8
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число меньше
# Компьютер предполагает, что это число... 27
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число меньше
# Компьютер предполагает, что это число... 27
# Загаданное число меньше
# Компьютер предполагает, что это число... 26
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число больше
# Компьютер предполагает, что это число... 24
# Загаданное число меньше
# Компьютер предполагает, что это число... 23
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число меньше
# Компьютер предполагает, что это число... 66
# Загаданное число больше
# Компьютер предполагает, что это число... 68
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число больше
# Компьютер предполагает, что это число... 24
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число меньше
# Компьютер предполагает, что это число... 27
# Загаданное число больше
# Компьютер предполагает, что это число... 28
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число меньше
# Компьютер предполагает, что это число... 59
# Загаданное число меньше
# Компьютер предполагает, что это число... 58
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число больше
# Компьютер предполагает, что это число... 85
# Загаданное число меньше
# Компьютер предполагает, что это число... 84
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число меньше
# Компьютер предполагает, что это число... 41
# Загаданное число меньше
# Компьютер предполагает, что это число... 40
# Загаданное число меньше
# Компьютер предполагает, что это число... 39
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Загаданное число меньше
# Компьютер предполагает, что это число... 9
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число больше
# Компьютер предполагает, что это число... 35
# Загаданное число меньше
# Компьютер предполагает, что это число... 34
# Загаданное число меньше
# Компьютер предполагает, что это число... 33
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число больше
# Компьютер предполагает, что это число... 35
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Загаданное число больше
# Компьютер предполагает, что это число... 12
# Загаданное число меньше
# Компьютер предполагает, что это число... 11
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число больше
# Компьютер предполагает, что это число... 24
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число меньше
# Компьютер предполагает, что это число... 16
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число меньше
# Компьютер предполагает, что это число... 27
# Загаданное число меньше
# Компьютер предполагает, что это число... 26
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число меньше
# Компьютер предполагает, что это число... 91
# Загаданное число больше
# Компьютер предполагает, что это число... 93
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число больше
# Компьютер предполагает, что это число... 47
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число больше
# Компьютер предполагает, что это число... 35
# Загаданное число меньше
# Компьютер предполагает, что это число... 34
# Загаданное число меньше
# Компьютер предполагает, что это число... 33
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число меньше
# Компьютер предполагает, что это число... 91
# Загаданное число меньше
# Компьютер предполагает, что это число... 90
# Загаданное число меньше
# Компьютер предполагает, что это число... 89
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число больше
# Компьютер предполагает, что это число... 24
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число больше
# Компьютер предполагает, что это число... 56
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число меньше
# Компьютер предполагает, что это число... 66
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Загаданное число больше
# Компьютер предполагает, что это число... 78
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число меньше
# Компьютер предполагает, что это число... 2
# Загаданное число меньше
# Компьютер предполагает, что это число... 1
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Загаданное число больше
# Компьютер предполагает, что это число... 78
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число меньше
# Компьютер предполагает, что это число... 52
# Загаданное число больше
# Компьютер предполагает, что это число... 53
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число больше
# Компьютер предполагает, что это число... 85
# Загаданное число больше
# Компьютер предполагает, что это число... 87
# Загаданное число меньше
# Компьютер предполагает, что это число... 86
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Загаданное число меньше
# Компьютер предполагает, что это число... 71
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число меньше
# Компьютер предполагает, что это число... 2
# Загаданное число больше
# Компьютер предполагает, что это число... 3
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число меньше
# Компьютер предполагает, что это число... 91
# Загаданное число больше
# Компьютер предполагает, что это число... 93
# Загаданное число меньше
# Компьютер предполагает, что это число... 92
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Загаданное число меньше
# Компьютер предполагает, что это число... 76
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Загаданное число меньше
# Компьютер предполагает, что это число... 9
# Загаданное число меньше
# Компьютер предполагает, что это число... 8
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Загаданное число больше
# Компьютер предполагает, что это число... 78
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Загаданное число больше
# Компьютер предполагает, что это число... 74
# Загаданное число меньше
# Компьютер предполагает, что это число... 73
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Загаданное число меньше
# Компьютер предполагает, что это число... 76
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число меньше
# Компьютер предполагает, что это число... 21
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число меньше
# Компьютер предполагает, что это число... 29
# Загаданное число больше
# Компьютер предполагает, что это число... 31
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число больше
# Компьютер предполагает, что это число... 35
# Загаданное число больше
# Компьютер предполагает, что это число... 37
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число больше
# Компьютер предполагает, что это число... 10
# Загаданное число меньше
# Компьютер предполагает, что это число... 9
# Загаданное число меньше
# Компьютер предполагает, что это число... 8
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число больше
# Компьютер предполагает, что это число... 47
# Загаданное число меньше
# Компьютер предполагает, что это число... 46
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число меньше
# Компьютер предполагает, что это число... 59
# Загаданное число меньше
# Компьютер предполагает, что это число... 58
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число больше
# Компьютер предполагает, что это число... 85
# Загаданное число меньше
# Компьютер предполагает, что это число... 84
# Загаданное число меньше
# Компьютер предполагает, что это число... 83
# Верно
#
#
# ...
# Загаданное число больше
# Компьютер предполагает, что это число... 43
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число больше
# Компьютер предполагает, что это число... 47
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число меньше
# Компьютер предполагает, что это число... 52
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Загаданное число больше
# Компьютер предполагает, что это число... 74
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число меньше
# Компьютер предполагает, что это число... 41
# Загаданное число больше
# Компьютер предполагает, что это число... 43
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число меньше
# Компьютер предполагает, что это число... 16
# Загаданное число меньше
# Компьютер предполагает, что это число... 15
# Загаданное число меньше
# Компьютер предполагает, что это число... 14
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число больше
# Компьютер предполагает, что это число... 24
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число больше
# Компьютер предполагает, что это число... 47
# Загаданное число меньше
# Компьютер предполагает, что это число... 46
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число больше
# Компьютер предполагает, что это число... 97
# Загаданное число меньше
# Компьютер предполагает, что это число... 96
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число меньше
# Компьютер предполагает, что это число... 52
# Загаданное число больше
# Компьютер предполагает, что это число... 53
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число меньше
# Компьютер предполагает, что это число... 32
# Загаданное число больше
# Компьютер предполагает, что это число... 35
# Загаданное число меньше
# Компьютер предполагает, что это число... 34
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число больше
# Компьютер предполагает, что это число... 56
# Загаданное число меньше
# Компьютер предполагает, что это число... 55
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число меньше
# Компьютер предполагает, что это число... 16
# Загаданное число меньше
# Компьютер предполагает, что это число... 15
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число меньше
# Компьютер предполагает, что это число... 59
# Загаданное число меньше
# Компьютер предполагает, что это число... 58
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число больше
# Компьютер предполагает, что это число... 62
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число меньше
# Компьютер предполагает, что это число... 41
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Загаданное число больше
# Компьютер предполагает, что это число... 74
# Загаданное число меньше
# Компьютер предполагает, что это число... 73
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число меньше
# Компьютер предполагает, что это число... 66
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число больше
# Компьютер предполагает, что это число... 19
# Загаданное число больше
# Компьютер предполагает, что это число... 22
# Загаданное число больше
# Компьютер предполагает, что это число... 24
# Загаданное число меньше
# Компьютер предполагает, что это число... 23
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число меньше
# Компьютер предполагает, что это число... 2
# Загаданное число больше
# Компьютер предполагает, что это число... 3
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число больше
# Компьютер предполагает, что это число... 85
# Загаданное число больше
# Компьютер предполагает, что это число... 87
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число меньше
# Компьютер предполагает, что это число... 2
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Загаданное число больше
# Компьютер предполагает, что это число... 74
# Загаданное число меньше
# Компьютер предполагает, что это число... 73
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Загаданное число меньше
# Компьютер предполагает, что это число... 52
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число больше
# Компьютер предполагает, что это число... 69
# Загаданное число больше
# Компьютер предполагает, что это число... 72
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Загаданное число больше
# Компьютер предполагает, что это число... 78
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число больше
# Компьютер предполагает, что это число... 47
# Загаданное число больше
# Компьютер предполагает, что это число... 49
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Загаданное число меньше
# Компьютер предполагает, что это число... 2
# Загаданное число меньше
# Компьютер предполагает, что это число... 1
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число меньше
# Компьютер предполагает, что это число... 41
# Загаданное число больше
# Компьютер предполагает, что это число... 43
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Загаданное число меньше
# Компьютер предполагает, что это число... 41
# Загаданное число меньше
# Компьютер предполагает, что это число... 40
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число меньше
# Компьютер предполагает, что это число... 13
# Загаданное число меньше
# Компьютер предполагает, что это число... 7
# Загаданное число меньше
# Компьютер предполагает, что это число... 4
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число больше
# Компьютер предполагает, что это число... 60
# Загаданное число меньше
# Компьютер предполагает, что это число... 59
# Загаданное число меньше
# Компьютер предполагает, что это число... 58
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число меньше
# Компьютер предполагает, что это число... 63
# Загаданное число меньше
# Компьютер предполагает, что это число... 57
# Загаданное число меньше
# Компьютер предполагает, что это число... 54
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число меньше
# Компьютер предполагает, что это число... 25
# Загаданное число больше
# Компьютер предполагает, что это число... 38
# Загаданное число больше
# Компьютер предполагает, что это число... 44
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число больше
# Компьютер предполагает, что это число... 97
# Загаданное число больше
# Компьютер предполагает, что это число... 99
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число больше
# Компьютер предполагает, что это число... 94
# Загаданное число больше
# Компьютер предполагает, что это число... 97
# Загаданное число больше
# Компьютер предполагает, что это число... 99
# Загаданное число меньше
# Компьютер предполагает, что это число... 98
# Верно
#
#
# Компьютер предполагает, что это число... 50
# Загаданное число больше
# Компьютер предполагает, что это число... 75
# Загаданное число больше
# Компьютер предполагает, что это число... 88
# Загаданное число меньше
# Компьютер предполагает, что это число... 82
# Загаданное число меньше
# Компьютер предполагает, что это число... 79
# Загаданное число меньше
# Компьютер предполагает, что это число... 77
# Загаданное число меньше
# Компьютер предполагает, что это число... 76
# Верно
#
#
# Ваш алгоритм угадывает число в среднем за 6 попыток
